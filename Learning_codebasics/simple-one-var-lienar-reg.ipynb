# %% [markdown]
# # Simple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data = pd.read_csv("tvmarketing.csv")
data.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
# %matplotlib inline
plt.xlabel("TV")
plt.ylabel("Sales")
plt.scatter(data.TV , data.Sales , color="Red" , marker="+")
plt.plot(data.TV , reg.predict(data[["TV"]]) , color="blue")

# %%
reg  = linear_model.LinearRegression()
reg.fit(data[["TV"]] , data.Sales)
# Out:
# LinearRegression()

# %%
reg.predict([[100]])
# Out:
# /src/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11.78625759])
